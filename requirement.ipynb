# %%
# %pip install flask
# Out:
# ...
#
#    ----- ---------------------------------- 1/7 [itsdangerous]
#    ----------- ---------------------------- 2/7 [click]
#    ----------- ---------------------------- 2/7 [click]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------- ----------------- 4/7 [werkzeug]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------- ----------- 5/7 [jinja2]
#    ---------------------------------- ----- 6/7 [flask]
#    ---------------------------------- ----- 6/7 [flask]
# ...

# %%
# %pip install groq
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.6 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/14 [typing-extensions]
#    -- -------------------------------------  1/14 [sniffio]
#    ----- ----------------------------------  2/14 [idna]
#    ----- ----------------------------------  2/14 [idna]
#    ----- ----------------------------------  2/14 [idna]
#    ----- ----------------------------------  2/14 [idna]
#    -------- -------------------------------  3/14 [h11]
#    -------- -------------------------------  3/14 [h11]
#    -------- -------------------------------  3/14 [h11]
#    -------- -------------------------------  3/14 [h11]
#    -------- -------------------------------  3/14 [h11]
# ...
